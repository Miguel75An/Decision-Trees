# %% [markdown]
# #### =========================
# #### MIGUEL DOMINGUEZ
# #### CSC 59929
# #### Machine Learning
# #### Prof. Erik K. Grimmelmann
# #### Date: 10/15/17
# #### Homework Week 7
# #### =========================

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from matplotlib.ticker import MaxNLocator 
from matplotlib.colors import ListedColormap
from IPython.display import Image
# %matplotlib inline
import graphviz 
from graphviz import Digraph
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz

# %% [markdown]
# # Discussion:
#
# #### This part of the assigment was to fit the Decision Tree model with the Iris Dataset. Here, we will test different criterion such as entropy and gini. As well, we will play with the percentage of training and testing data.
#
# #### [0] We obtain the Iris DataFrame and get the X matrix which as four columns for four features. As well, we get the class vector Y which has 0, for Setosa, 1 for Versicolor and 2 for Virginica.
#
# #### [1] We split the data into training and testing data. (50% training and 50%testing, later we split in 70% training and 30 %testing)
#
# #### [2] We fit the Decision Tree models for different depths as well we do it for entropy and gini impurities measures.
#
# #### [3] We collect the error percetages for the models
#
# #### [4] Plot the actual Decision Trees (orange = Setosa, green = Versicolor, purple = Virginica)
#
#
#
# # Conclusion:
#
# #### We were able to fit the Decion Trees with the Iris Dataset and obtain interesting results.
#
# #### It is essential to mention that we are working with all four features for the flowers. Features with the most significant value or more divisible power are found at the top of the Decision Tree. This means that the Decision Tree will need less levels to reach a final result. To demonstrate this, take a look at any of the plotted Trees, the Setosa Class is easily classified by checking if the Sepal Width is less or equal to - 0.59 (standardized). The other classes need more levels to reach a classification. This tells us in general that Feature picking for a Decision Tree model is important since it reduces time complexity and cost of computation. (meaning it is always better to have a smaller efficient tree rather than a large rebundant tree)
#
# #### For the Measurments of Impurity, I experimented with the Entropy and Gini measures. I tried to look for the Classification Error impurity measure but was unsuccesful in finding it for the scikit learn Decison Tree model. Not supported. However, Entropy and Gini work in a very similar way. They play an important role in determining how to make a split and the number of samples needed for the deeper level nodes. Eventually both impurity measures lead us to the class classification. Something important to notice is that for both Decision Trees I got the same structure. As well, the errors were almost the same for both Entropy and Gini Trees. My observation makes me think that we need more data to build the Decison Trees, in those examples we work with the small Iris Dataset. Perhaps working with larger datasets will allow us to see the differences between Entropy and Gini.
#
# #### We saw a difference in the size of training data and testing data for the Decision Trees. When using only 50% training data the model had 9 nodes while using 70% give us 13 nodes to classify the flowers. This means that the mode data given to fit the model will help us build a tree with more branches that will classify each testing sample with more accuracy. As well, the error values for 70% are smaller than the error values for 50%.

# %%
#Obtain Iris Dataset and save it to a Pandas Frame
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header = None)
#Rename columns
new_columns = ['Sepal Length [0]', 'Sepal Width [1]', 'Petal Length [2]', 'Petal Width [3]','Class']
iris.columns = new_columns
iris.head()
# Out:
#    Sepal Length [0]  Sepal Width [1]  Petal Length [2]  Petal Width [3]  \
# 0               5.1              3.5               1.4              0.2
# 1               4.9              3.0               1.4              0.2
# 2               4.7              3.2               1.3              0.2
# 3               4.6              3.1               1.5              0.2
# 4               5.0              3.6               1.4              0.2
#
#          Class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
#We use all 3 flower clases (SVV means Setosa & Versicolor & Virginica)
SVV = iris.iloc[:,:].values

#Standardize the features
for i in range(0,4):
    SVV[:,i] = (SVV[:,i] - SVV[:,i].mean()) / SVV[:,i].std()   

#Samples    
X = SVV[:,0:4]    

#Get class vector
Y = SVV[:,4]
for i in range(0,len(Y)):
    if Y[i] == 'Iris-setosa':
        Y[i] = 0
    elif Y[i] == 'Iris-versicolor':
         Y[i] = 1
    else:
         Y[i] = 2
#Convert Y to list
Y = Y.tolist()

# %% [markdown]
# # Training Data 50% Testing Data 50%

# %%
# Split data into 50% training and 50% test data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
         X, Y, test_size=0.50, random_state=0)

# %%
# Fit for various depth trees
MaxDepth = 5
Errors = np.zeros((MaxDepth,2))

print ('Max Depth, Training, Test')

for i in range(0,MaxDepth):
    tree = DecisionTreeClassifier(criterion='entropy', max_depth=i+1, random_state=0)
    tree.fit(X_train, Y_train)

    X_combined = np.vstack((X_train, X_test))
    Y_combined = np.hstack((Y_train, Y_test))

    # optional outputs
    z = tree.apply(X_combined)
    #print(z)
    dp = tree.decision_path(X_combined)
    #print (dp)
      
    Errors[i,0] = 1 - tree.score(X_train,Y_train)
    Errors[i,1] = 1 - tree.score(X_test,Y_test)
    print(i+1,Errors[i,0],Errors[i,1])
# Out:
# Max Depth, Training, Test
# 1 0.266666666667 0.4
# 2 0.0266666666667 0.106666666667
# 3 0.0133333333333 0.04
# 4 0.0 0.04
# 5 0.0 0.04

# %% [markdown]
# ## Entropy

# %%
#Plot the final decision tree
export_graphviz(tree, out_file='T10.dot',filled= True, class_names=['Setosa','Versicolor','Virginica'],  rounded=True, 
                feature_names=['Sepal Length [0]', 'Sepal Width [1]', 'Petal Length [2]', 'Petal Width [3]'])
with open('T10.dot') as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
# Fit for various depth trees
MaxDepth = 5
Errors = np.zeros((MaxDepth,2))

print ('Max Depth, Training, Test')

for i in range(0,MaxDepth):
    tree = DecisionTreeClassifier(criterion='gini', max_depth=i+1, random_state=0)
    tree.fit(X_train, Y_train)

    X_combined = np.vstack((X_train, X_test))
    Y_combined = np.hstack((Y_train, Y_test))

    # optional outputs
    z = tree.apply(X_combined)
    #print(z)
    dp = tree.decision_path(X_combined)
    #print (dp)
      
    Errors[i,0] = 1 - tree.score(X_train,Y_train)
    Errors[i,1] = 1 - tree.score(X_test,Y_test)
    print(i+1,Errors[i,0],Errors[i,1])
# Out:
# Max Depth, Training, Test
# 1 0.266666666667 0.4
# 2 0.0266666666667 0.106666666667
# 3 0.0133333333333 0.04
# 4 0.0 0.04
# 5 0.0 0.04

# %% [markdown]
# ## Gini

# %%
#Plot the final decision gree
export_graphviz(tree, out_file='T11.dot', filled= True, class_names=['Setosa','Versicolor','Virginica'],  rounded=True, 
                feature_names=['Sepal Length [0]', 'Sepal Width [1]', 'Petal Length [2]', 'Petal Width [3]'])
with open('T11.dot') as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %% [markdown]
# # Training Data 70% Testing Data 30%

# %%
# Split data into 70% training and 30% test data
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
         X, Y, test_size=0.30, random_state=0)

# %%
# Fit for various depth trees
MaxDepth = 5
Errors = np.zeros((MaxDepth,2))

print ('Max Depth, Training, Test')

for i in range(0,MaxDepth):
    tree = DecisionTreeClassifier(criterion='entropy', max_depth=i+1, random_state=0)
    tree.fit(X_train, Y_train)

    X_combined = np.vstack((X_train, X_test))
    Y_combined = np.hstack((Y_train, Y_test))

    # optional outputs
    z = tree.apply(X_combined)
    #print(z)
    dp = tree.decision_path(X_combined)
    #print (dp)
      
    Errors[i,0] = 1 - tree.score(X_train,Y_train)
    Errors[i,1] = 1 - tree.score(X_test,Y_test)
    print(i+1,Errors[i,0],Errors[i,1])
# Out:
# Max Depth, Training, Test
# 1 0.304761904762 0.4
# 2 0.0380952380952 0.0888888888889
# 3 0.0190476190476 0.0222222222222
# 4 0.0 0.0222222222222
# 5 0.0 0.0222222222222

# %% [markdown]
# ## Entropy

# %%
#Plot the final decision gree
export_graphviz(tree, out_file='T12.dot',filled= True, class_names=['Setosa','Versicolor','Virginica'],  rounded=True, 
                feature_names=['Sepal Length [0]', 'Sepal Width [1]', 'Petal Length [2]', 'Petal Width [3]'])
with open('T12.dot') as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
# Fit for various depth trees
MaxDepth = 5
Errors = np.zeros((MaxDepth,2))

print ('Max Depth, Training, Test')

for i in range(0,MaxDepth):
    tree = DecisionTreeClassifier(criterion='gini', max_depth=i+1, random_state=0)
    tree.fit(X_train, Y_train)

    X_combined = np.vstack((X_train, X_test))
    Y_combined = np.hstack((Y_train, Y_test))

    # optional outputs
    #z = tree.apply(X_combined)
    #print(z)
    #dp = tree.decision_path(X_combined)
    #print (dp)
      
    Errors[i,0] = 1 - tree.score(X_train,Y_train)
    Errors[i,1] = 1 - tree.score(X_test,Y_test)
    print(i+1,Errors[i,0],Errors[i,1])
# Out:
# Max Depth, Training, Test
# 1 0.304761904762 0.4
# 2 0.0380952380952 0.0888888888889
# 3 0.0190476190476 0.0222222222222
# 4 0.0 0.0222222222222
# 5 0.0 0.0222222222222

# %% [markdown]
# ## Gini

# %%
#Plot the final decision gree
export_graphviz(tree, out_file='T13.dot',filled= True, class_names=['Setosa','Versicolor','Virginica'],  rounded=True, 
                feature_names=['Sepal Length [0]', 'Sepal Width [1]', 'Petal Length [2]', 'Petal Width [3]'])
with open('T13.dot') as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
